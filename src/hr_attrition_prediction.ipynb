# %% [markdown]
# # 🧑‍💼 HR Attrition Prediction (Classification)

# %% [markdown]
# Predict whether an employee is at risk of **attrition** using job, compensation, and satisfaction features. Includes logistic regression + random forest and a **real‑data trainer**.

# %% [markdown]
# ## Setup

# %%
import pandas as pd
pd.read_csv('data/sample_hr_attrition.csv').head()

# %% [markdown]
# ### Embedded previews
# ![RF Feature Importance](../results/rf_feature_importance.png)
#
# ![ROC RF](../results/roc_curve_rf.png)
#
# ![Confusion RF](../results/confusion_matrix_rf.png)
